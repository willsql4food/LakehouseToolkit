-- %% [markdown]
-- # Tables

-- %%
select      @@SERVERNAME srvr, DB_NAME() dbName, s.name schemaName, t.name tableName
        ,   coalesce(hs.name, '') history_schema, coalesce(ht.name, '') history_table, t.data_retention_period, t.data_retention_period_unit_desc
from        sys.schemas s
join        sys.tables t on t.schema_id = s.schema_id
left join   sys.tables ht on ht.object_id = t.history_table_id
left join   sys.schemas hs on hs.schema_id = ht.schema_id
order by    s.name, t.name
-- Out:
-- (18 rows affected)
-- Total execution time: 00:00:00.041
-- <table><tr><th>srvr</th><th>dbName</th><th>schemaName</th><th>tableName</th><th>history_schema</th><th>history_table</th><th>data_retention_period</th><th>data_retention_period_unit_desc</th></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>colors</td><td>history</td><td>colors</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>customers</td><td>history</td><td>customers</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>inventory</td><td>history</td><td>inventory</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>items</td><td>history</td><td>items</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>order_items</td><td>history</td><td>order_items</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>orders</td><td>history</td><td>orders</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>products</td><td>history</td><td>products</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>sizes</td><td>history</td><td>sizes</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td>words</td><td>history</td><td>words</td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>colors</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>customers</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>inventory</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>items</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>order_items</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>orders</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>products</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>sizes</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>history</td><td>words</td><td></td><td></td><td>-1</td><td>INFINITE</td></tr></table>

-- %% [markdown]
-- # With Column Definitions

-- %%
select		@@SERVERNAME srvr, DB_NAME() dbName, s.name schemaName, t.name tableName
		,	c.column_id, c.name columnName, c.generated_always_type, c.generated_always_type_desc
		,	coalesce(ix.name, '') indexName, coalesce(ix.is_primary_key, 0) is_primary_key
		,	coalesce(ic.index_column_id, -1) index_column_id
		,	ty.*
from		sys.schemas s
join		sys.tables t on t.schema_id = s.schema_id
join		sys.columns c on c.object_id = t.object_id
join		sys.types ty on ty.user_type_id = c.user_type_id
left join	sys.index_columns ic on ic.object_id = t.object_id and ic.column_id = c.column_id
left join	sys.indexes ix on ix.object_id = t.object_id and ic.index_id = ix.index_id
order by	s.name, t.name, ix.name, c.column_id, ic.index_column_id
-- Out:
-- (114 rows affected)
-- Total execution time: 00:00:00.044
-- <table><tr><th>srvr</th><th>dbName</th><th>schemaName</th><th>tableName</th><th>column_id</th><th>columnName</th><th>generated_always_type</th><th>generated_always_type_desc</th><th>indexName</th><th>is_primary_key</th><th>index_column_id</th><th>name</th><th>system_type_id</th><th>user_type_id</th><th>schema_id</th><th>principal_id</th><th>max_length</th><th>precision</th><th>scale</th><th>collation_name</th><th>is_nullable</th><th>is_user_defined</th><th>is_assembly_type</th><th>default_object_id</th><th>rule_object_id</th><th>is_table_type</th></tr><tr><td>SSC-IS568\ACB</td><td>SevenLetterTees</td><td>dbo</td><td