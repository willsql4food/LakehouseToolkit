# %%
# list = ['events_20250101', 'events_20250102', 'events_20250103', 'events_20250104', 'events_20250106']
list = ['events_20250101']
list.sort()
min = list[0][-8:]
max = list[-1][-8:]

print(f"min: {min}, max: {max}")

# %%
dbutils.notebook.run('./Work-on-a-range', 30, {'StartDate': min, 'EndDate': max})
